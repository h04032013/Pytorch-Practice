# %% [markdown]
# <h1>Linear regression: Training and Validation Data</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to use learning rate hyperparameter to improve your model result.  .</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will learn to select the best learning rate by using validation data.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#LR_Loader_Cost">Create a Linear Regression Object, Data Loader and Criterion Function</a></li>
#     <li><a href="#LR_Hyper">Different learning rates and Data Structures to Store results for Different Hyperparameters</a></li>
#     <li><a href="#Model">Train different modules for different Hyperparameters</a></li>
#     <li><a href="#Result">View Results</a></li>
# </ul>
#
# <p>Estimated Time Needed: <strong>30 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# We'll need the following libraries and set the random seed.

# %%
# Import libraries we need for this lab, and set the random seed

from torch import nn
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# First, we'll create some artificial data in a dataset class. The class will include the option to produce training data or validation data. The training data will include outliers.

# %%
# Create Data class

from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    
    # Constructor
    def __init__(self, train = True):
            self.x = torch.arange(-3, 3, 0.1).view(-1, 1)
            self.f = -3 * self.x + 1
            self.y = self.f + 0.1 * torch.randn(self.x.size())
            self.len = self.x.shape[0]
            
            #outliers 
            if train == True:
                self.y[0] = 0
                self.y[50:55] = 20
            else:
                pass
      
    # Getter
    def __getitem__(self, index):    
        return self.x[index], self.y[index]
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Create two objects: one that contains training data and a second that contains validation data. Assume that the training data has the outliers.

# %%
# Create training dataset and validation dataset

train_data = Data()
val_data = Data(train = False)

# %% [markdown]
# Overlay the training points in red over the function that generated the data. Notice the outliers at x=-3 and around x=2:

# %%
# Plot out training points

plt.plot(train_data.x.numpy(), train_data.y.numpy(), 'xr',label="training data ")
plt.plot(train_data.x.numpy(), train_data.f.numpy(),label="true function  ")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <h2 id="LR_Loader_Cost">Create a Linear Regression Object,  Data Loader, and Criterion Function</h2>

# %%
# Create Linear Regression Class

from torch import nn

class linear_regression(nn.Module):
    
    # Constructor
    def __init__(self, input_size, output_size):
        super(linear_regression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
    
    # Prediction function
    def forward(self, x):
        yhat = self.linear(x)
        return yhat

# %% [markdown]
# Create the criterion function and a <code>DataLoader</code> object:

# %%
# Create MSELoss function and DataLoader

criterion = nn.MSELoss()
trainloader = DataLoader(dataset = train_data, batch_size = 1)

# %% [markdown]
# <h2 id="LR_Hyper">Different learning rates and Data Structures to Store results for different Hyperparameters</h2>

# %% [markdown]
# Create a list with different learning rates and a tensor (can be a list) for the training and validating cost/total loss. Include the list MODELS, which stores the training model for every value of the learning rate.

# %%
# Create Learning Rate list, the error lists and the MODELS list

learning_rates=[0.0001, 0.001, 0.01, 0.1]

train_error=torch.zeros(len(learning_rates))
validation_error=torch.zeros(len(learning_rates))

MODELS=[]

# %% [markdown]
# <h2 id="Model">Train different models  for different Hyperparameters</h2>

# %% [markdown]
# Try different values of learning rates, perform stochastic gradient descent, and save the results on the training data and validation data. Finally, save each model in a list.

# %%
# Define the train model function and train the model

def train_model_with_lr (iter, lr_list):
    
    # iterate through different learning rates 
    for i, lr in enumerate(lr_list):
        model = linear_regression(1, 1)
        optimizer = optim.SGD(model.parameters(), lr = lr)
        for epoch in range(iter):
            for x, y in trainloader:
                yhat = model(x)
                loss = criterion(yhat, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
        # train data
        Yhat = model(train_data.x)
        train_loss = criterion(Yhat, train_data.y)
        train_error[i] = train_loss.item()
    
        # validation data
        Yhat = model(val_data.x)
        val_loss = criterion(Yhat, val_data.y)
        validation_error[i] = val_loss.item()
        MODELS.append(model)

train_model_with_lr(10, learning_rates)

# %% [markdown]
# <h2 id="Result">View the Results</h2>

# %% [markdown]
# Plot the training loss and validation loss for each learning rate:

# %%
# Plot the training loss and validation loss

plt.semilogx(np.array(learning_rates), train_error.numpy(), label = 'training loss/total Loss')
plt.semilogx(np.array(learning_rates), validation_error.numpy(), label = 'validation cost/total Loss')
plt.ylabel('Cost\ Total Loss')
plt.xlabel('learning rate')
plt.legend()
plt.show()

# %% [markdown]
# Produce a prediction by using the validation data for each model:

# %%
# Plot the predictions

i = 0
for model, learning_rate in zip(MODELS, learning_rates):
    yhat = model(val_data.x)
    plt.plot(val_data.x.numpy(), yhat.detach().numpy(), label = 'lr:' + str(learning_rate))
    print(i, yhat.detach().numpy()[0:3])
    i+=1
plt.plot(val_data.x.numpy(), val_data.f.numpy(), 'or', label = 'validation data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 0 [[3.1795301]
#  [3.0751655]
#  [2.9708009]]
# 1 [[5.6636047]
#  [5.5469418]
#  [5.4302783]]
# 2 [[6.5981956]
#  [6.463896 ]
#  [6.329595 ]]
# 3 [[14.06069  ]
#  [13.6396475]
#  [13.218605 ]]

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# The object <code>good_model</code> is the best performing model. Use the train loader to get the data samples x and y. Produce an estimate for <code>yhat</code> and print it out for every sample in a for a loop. Compare it to the actual prediction <code>y</code>.

# %%
good_model = MODELS[np.argmin(validation_error)]

#Type your code here: 

for x,y in trainloader:
    print("yhat = ", model(x)," y: ", y)
# Out:
# yhat =  tensor([[14.0607]], grad_fn=<AddmmBackward0>)  y:  tensor([[0.]])
# yhat =  tensor([[13.6396]], grad_fn=<AddmmBackward0>)  y:  tensor([[9.7115]])
# yhat =  tensor([[13.2186]], grad_fn=<AddmmBackward0>)  y:  tensor([[9.4670]])
# yhat =  tensor([[12.7976]], grad_fn=<AddmmBackward0>)  y:  tensor([[8.9578]])
# yhat =  tensor([[12.3765]], grad_fn=<AddmmBackward0>)  y:  tensor([[8.9418]])
# yhat =  tensor([[11.9555]], grad_fn=<AddmmBackward0>)  y:  tensor([[8.5428]])
# yhat =  tensor([[11.5344]], grad_fn=<AddmmBackward0>)  y:  tensor([[8.2201]])
# yhat =  tensor([[11.1134]], grad_fn=<AddmmBackward0>)  y:  tensor([[7.7821]])
# yhat =  tensor([[10.6924]], grad_fn=<AddmmBackward0>)  y:  tensor([[7.5772]])
# yhat =  tensor([[10.2713]], grad_fn=<AddmmBackward0>)  y:  tensor([[7.2353]])
# yhat =  tensor([[9.8503]], grad_fn=<AddmmBackward0>)  y:  tensor([[7.1230]])
# yhat =  tensor([[9.4292]], grad_fn=<AddmmBackward0>)  y:  tensor([[6.6735]])
# yhat =  tensor([[9.0082]], grad_fn=<AddmmBackward0>)  y:  tensor([[6.2168]])
# yhat =  tensor([[8.5871]], grad_fn=<AddmmBackward0>)  y:  tensor([[6.0602]])
# yhat =  tensor([[8.1661]], grad_fn=<AddmmBackward0>)  y:  tensor([[5.8320]])
# yhat =  tensor([[7.7451]], grad_fn=<AddmmBackward0>)  y:  tensor([[5.5672]])
# yhat =  tensor([[7.3240]], grad_fn=<AddmmBackward0>)  y:  tensor([[5.2951]])
# yhat =  tensor([[6.9030]], grad_fn=<AddmmBackward0>)  y:  tensor([[4.9739]])
# yhat =  tensor([[6.4819]], grad_fn=<AddmmBackward0>)  y:  tensor([[4.6023]])
# yhat =  tensor([[6.0609]], grad_fn=<AddmmBackward0>)  y:  tensor([[4.2697]])
# yhat =  tensor([[5.6398]], grad_fn=<AddmmBackward0>)  y:  tensor([[3.9891]])
# yhat =  tensor([[5.2188]], grad_fn=<AddmmBackward0>)  y:  tensor([[3.6411]])
# yhat =  tensor([[4.7978]], grad_fn=<AddmmBackward0>)  y:  tensor([[3.4260]])
# yhat =  tensor([[4.3767]], grad_fn=<AddmmBackward0>)  y:  tensor([[3.1710]])
# yhat =  tensor([[3.9557]], grad_fn=<AddmmBackward0>)  y:  tensor([[2.8018]])
# yhat =  tensor([[3.5346]], grad_fn=<AddmmBackward0>)  y:  tensor([[2.5466]])
# yhat =  tensor([[3.1136]], grad_fn=<AddmmBackward0>)  y:  tensor([[2.1613]])
# yhat =  tensor([[2.6925]], grad_fn=<AddmmBackward0>)  y:  tensor([[1.8155]])
# yhat =  tensor([[2.2715]], grad_fn=<AddmmBackward0>)  y:  tensor([[1.4039]])
# yhat =  tensor([[1.8505]], grad_fn=<AddmmBackward0>)  y:  tensor([[1.3479]])
# yhat =  tensor([[1.4294]], grad_fn=<AddmmBackward0>)  y:  tensor([[0.9293]])
# yhat =  tensor([[1.0084]], grad_fn=<AddmmBackward0>)  y:  tensor([[0.7055]])
# yhat =  tensor([[0.5873]], grad_fn=<AddmmBackward0>)  y:  tensor([[0.3460]])
# yhat =  tensor([[0.1663]], grad_fn=<AddmmBackward0>)  y:  tensor([[0.0759]])
# yhat =  tensor([[-0.2548]], grad_fn=<AddmmBackward0>)  y:  tensor([[-0.2039]])
# yhat =  tensor([[-0.6758]], grad_fn=<AddmmBackward0>)  y:  tensor([[-0.3616]])
# yhat =  tensor([[-1.0968]], grad_fn=<AddmmBackward0>)  y:  tensor([[-0.9160]])
# yhat =  tensor([[-1.5179]], grad_fn=<AddmmBackward0>)  y:  tensor([[-1.0513]])
# yhat =  tensor([[-1.9389]], grad_fn=<AddmmBackward0>)  y:  tensor([[-1.3018]])
# yhat =  tensor([[-2.3600]], grad_fn=<AddmmBackward0>)  y:  tensor([[-1.7000]])
# yhat =  tensor([[-2.7810]], grad_fn=<AddmmBackward0>)  y:  tensor([[-1.7750]])
# yhat =  tensor([[-3.2021]], grad_fn=<AddmmBackward0>)  y:  tensor([[-2.2682]])
# yhat =  tensor([[-3.6231]], grad_fn=<AddmmBackward0>)  y:  tensor([[-2.7252]])
# yhat =  tensor([[-4.0441]], grad_fn=<AddmmBackward0>)  y:  tensor([[-2.8908]])
# yhat =  tensor([[-4.4652]], grad_fn=<AddmmBackward0>)  y:  tensor([[-3.1531]])
# yhat =  tensor([[-4.8862]], grad_fn=<AddmmBackward0>)  y:  tensor([[-3.4916]])
# yhat =  tensor([[-5.3073]], grad_fn=<AddmmBackward0>)  y:  tensor([[-3.8546]])
# yhat =  tensor([[-5.7283]], grad_fn=<AddmmBackward0>)  y:  tensor([[-4.0921]])
# yhat =  tensor([[-6.1493]], grad_fn=<AddmmBackward0>)  y:  tensor([[-4.3021]])
# yhat =  tensor([[-6.5704]], grad_fn=<AddmmBackward0>)  y:  tensor([[-4.4305]])
# yhat =  tensor([[-6.9914]], grad_fn=<AddmmBackward0>)  y:  tensor([[20.]])
# yhat =  tensor([[-7.4125]], grad_fn=<AddmmBackward0>)  y:  tensor([[20.]])
# yhat =  tensor([[-7.8335]], grad_fn=<AddmmBackward0>)  y:  tensor([[20.]])
# yhat =  tensor([[-8.2546]], grad_fn=<AddmmBackward0>)  y:  tensor([[20.]])
# yhat =  tensor([[-8.6756]], grad_fn=<AddmmBackward0>)  y:  tensor([[20.]])
# yhat =  tensor([[-9.0966]], grad_fn=<AddmmBackward0>)  y:  tensor([[-6.6690]])
# yhat =  tensor([[-9.5177]], grad_fn=<AddmmBackward0>)  y:  tensor([[-6.7293]])
# yhat =  tensor([[-9.9387]], grad_fn=<AddmmBackward0>)  y:  tensor([[-7.0161]])
# yhat =  tensor([[-10.3598]], grad_fn=<AddmmBackward0>)  y:  tensor([[-7.5627]])
# yhat =  tensor([[-10.7808]], grad_fn=<AddmmBackward0>)  y:  tensor([[-7.6646]])

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!--
# for x, y in trainloader:
#     print("yhat= ", model(x),"y", y)
# -->
